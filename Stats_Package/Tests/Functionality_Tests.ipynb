# %%
#Standard Packages
import pandas as pd
import numpy as np
import pickle
import qgrid
#import matplotlib.pyplot as plt
#Creates view function for qgrid
def view(df_test):
   return qgrid.show_grid(df_test, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 100})
import warnings
warnings.filterwarnings('ignore')
#import researchpy as rp
#from itertools import combinations
import scipy.stats #as stats
#from statsmodels.stats.multitest import multipletests
#import xlsxwriter

# %% [markdown]
# ### Importing Stats Packages
# * to install the Stats Packages you need to run pip install "git+https://github.com/rescueds/Stats_Package.git" in your terminal
# * then run the below to install all functions

# %%
###Stats Packages - Github import, tested in the Github_Tests notebook. 
#from Stats_Package.stats_descriptives_module import freqs, desc, xtab_cols, xtab_rows, xtab_all 
#from Stats_Package.stats_analysis_module import chi_sq, chisq_posthoc_bon, ttest_1sample, ttest_2sample, ttest_paired, KW_shape_assumption, corr_pearson

# %%
#Import directly from file for iterative testing
import import_ipynb
from stats_descriptives_module import freqs, desc,desc_subcats, xtab_cols, xtab_rows, xtab_all 
from stats_analysis_module import chi_sq, chisq_posthoc_bon, ttest_1sample, ttest_2sample, ttest_paired, KW_shape_assumption, corr_pearson

# %%
#read in data file
df = pd.read_pickle(r'TEST_FILE_BTH_Tracker_Preprocessed.pkl')
#includes only
df = df[df['Inclusion_Status'] == 1]

# %%
#If needed: 
#df.columns.to_list()

# %% [markdown]
# ## Tests - Frequencies_Xtabs_Functions

# %%
#frequencies function
#TO DISCUSS - played w/ formatting from the article, which was super fun - but could not export to xlsx, any value in html export? Or just in python? 
test_freq = freqs(df,['Project_Wave', 'Project_Year', 'State_Zip', 'Susceptible_Cig'], False)
test_freq
#view(test_freq)
# Out:
#           Variable              Values  Counts Percents
# 0     Project_Wave  Benchmark/Baseline    1752   42.31%
# 1     Project_Wave                FU_1    1345   32.48%
# 2     Project_Wave                FU_2    1044   25.21%
# 0     Project_Year                2020    1367   33.01%
# 1     Project_Year                2019    1109   26.78%
# 2     Project_Year                2022    1044   25.21%
# 3     Project_Year                2021     621    15.0%
# 0        State_Zip                  SC    1032   24.92%
# 1        State_Zip                  IN     957   23.11%
# 2        State_Zip                  KY     852   20.57%
# 3        State_Zip                  NV     679    16.4%
# 4        State_Zip                  OK     621    15.0%
# 0  Susceptible_Cig                   0    1634   39.46%
# 1  Susceptible_Cig                <NA>    1364   32.94%
# 2  Susceptible_Cig                   1    1143    27.6%

# %%
#descriptives function
test_desc = desc(df,['VAL_SCORE_ALT','VAL_SCORE_COUNTRY','VAL_SCORE_HH','VAL_SCORE_MAIN','VAL_SCORE_POP',])
#view(test_desc) 
test_desc
# Out:
#             Variable Summary_Stats      Results
# 0      VAL_SCORE_ALT         count  1637.000000
# 1      VAL_SCORE_ALT          mean     4.058949
# 2      VAL_SCORE_ALT           std     3.404931
# 3      VAL_SCORE_ALT           min     0.000000
# 4      VAL_SCORE_ALT           25%     1.000000
# 5      VAL_SCORE_ALT           50%     3.500000
# 6      VAL_SCORE_ALT           75%     6.500000
# 7      VAL_SCORE_ALT           max    14.000000
# 0  VAL_SCORE_COUNTRY         count  1637.000000
# 1  VAL_SCORE_COUNTRY          mean     1.977398
# 2  VAL_SCORE_COUNTRY           std     2.439007
# 3  VAL_SCORE_COUNTRY           min     0.000000
# 4  VAL_SCORE_COUNTRY           25%     0.000000
# 5  VAL_SCORE_COUNTRY           50%     1.000000
# 6  VAL_SCORE_COUNTRY           75%     3.000000
# 7  VAL_SCORE_COUNTRY           max    14.000000
# 0       VAL_SCORE_HH         count  1637.000000
# 1       VAL_SCORE_HH          mean     3.270617
# 2       VAL_SCORE_HH           std     2.843205
# 3       VAL_SCORE_HH           min     0.000000
# 4       VAL_SCORE_HH           25%     1.000000
# 5       VAL_SCORE_HH           50%     3.000000
# 6       VAL_SCORE_HH           75%     5.000000
# 7       VAL_SCORE_HH           max    13.000000
# 0     VAL_SCORE_MAIN         count  1637.000000
# 1     VAL_SCORE_MAIN          mean     3.929750
# 2     VAL_SCORE_MAIN           std     3.176349
# 3     VAL_SCORE_MAIN           min     0.000000
# 4     VAL_SCORE_MAIN           25%     1.000000
# 5     VAL_SCORE_MAIN           50%     3.500000
# 6     VAL_SCORE_MAIN           75%     6.000000
# 7     VAL_SCORE_MAIN           max    14.000000
# 0      VAL_SCORE_POP         count  1637.000000
# 1      VAL_SCORE_POP          mean     3.750153
# 2      VAL_SCORE_POP           std     3.079113
# 3      VAL_SCORE_POP           min     0.000000
# 4      VAL_SCORE_POP           25%     1.000000
# 5      VAL_SCORE_POP           50%     3.000000
# 6      VAL_SCORE_POP           75%     6.000000
# 7      VAL_SCORE_POP           max    14.000000

# %%
#descriptives w/ sub categories function
sub_cat_list = [0,1]
var_list = [ 'P30D_Alcohol_Cont','P30D_Marijuana_Cont','P30D_Marijuana_Vape_Cont']
subcats_test = desc_subcats(df,var_list, 'Gender_Female', sub_cat_list)
#view(subcats_test)
subcats_test
# Out:
#                    Variable  Subcategory Summary_Stats   Results
# 0         P30D_Alcohol_Cont            0         count     118.0
# 1         P30D_Alcohol_Cont            0          mean  0.788136
# 2         P30D_Alcohol_Cont            0           std  2.521198
# 3         P30D_Alcohol_Cont            0           min       0.0
# 4         P30D_Alcohol_Cont            0           25%       0.0
# 5         P30D_Alcohol_Cont            0           50%       0.0
# 6         P30D_Alcohol_Cont            0           75%       1.0
# 7         P30D_Alcohol_Cont            0           max      25.0
# 0       P30D_Marijuana_Cont            0         count     118.0
# 1       P30D_Marijuana_Cont            0          mean  1.974576
# 2       P30D_Marijuana_Cont            0           std  6.159506
# 3       P30D_Marijuana_Cont            0           min       0.0
# 4       P30D_Marijuana_Cont            0           25%       0.0
# 5       P30D_Marijuana_Cont            0           50%       0.0
# 6       P30D_Marijuana_Cont            0           75%       0.0
# 7       P30D_Marijuana_Cont            0           max      30.0
# 0  P30D_Marijuana_Vape_Cont            0         count     118.0
# 1  P30D_Marijuana_Vape_Cont            0          mean  0.855932
# 2  P30D_Marijuana_Vape_Cont            0           std  3.698638
# 3  P30D_Marijuana_Vape_Cont            0           min       0.0
# 4  P30D_Marijuana_Vape_Cont            0           25%       0.0
# 5  P30D_Marijuana_Vape_Cont            0           50%       0.0
# 6  P30D_Marijuana_Vape_Cont            0           75%       0.0
# 7  P30D_Marijuana_Vape_Cont            0           max      30.0
# 0         P30D_Alcohol_Cont            1         count     127.0
# 1         P30D_Alcohol_Cont            1          mean   1.84252
# 2         P30D_Alcohol_Cont            1           std  4.071631
# 3         P30D_Alcohol_Cont            1           min       0.0
# 4         P30D_Alcohol_Cont            1           25%       0.0
# 5         P30D_Alcohol_Cont            1           50%       0.0
# 6         P30D_Alcohol_Cont            1           75%       1.5
# 7         P30D_Alcohol_Cont            1           max      30.0
# 0       P30D_Marijuana_Cont            1         count     127.0
# 1       P30D_Marijuana_Cont            1          mean  2.944882
# 2       P30D_Marijuana_Cont            1           std   7.68766
# 3       P30D_Marijuana_Cont            1           min       0.0
# 4       P30D_Marijuana_Cont            1           25%       0.0
# 5       P30D_Marijuana_Cont            1           50%       0.0
# 6       P30D_Marijuana_Cont            1           75%       0.0
# 7       P30D_Marijuana_Cont            1           max      30.0
# 0  P30D_Marijuana_Vape_Cont            1         count     127.0
# 1  P30D_Marijuana_Vape_Cont            1          mean  2.440945
# 2  P30D_Marijuana_Vape_Cont            1           std  6.957528
# 3  P30D_Marijuana_Vape_Cont            1           min       0.0
# 4  P30D_Marijuana_Vape_Cont            1           25%       0.0
# 5  P30D_Marijuana_Vape_Cont            1           50%       0.0
# 6  P30D_Marijuana_Vape_Cont            1           75%       0.0
# 7  P30D_Marijuana_Vape_Cont            1           max      30.0

# %%
#cross tabs columns
test_cols = xtab_cols(df, ['P30D_VapeEcig', 'Susceptible_Cig'], 'Project_Year')
#view(test_cols)
test_cols
# Out:
# Project_Year  Counts/Percents               DV Values    2019    2020    2021  \
# 0                      Counts    P30D_VapeEcig      0     815    1103     485
# 3             Column Percents    P30D_VapeEcig      0  73.49%  80.69%   78.1%
# 1                      Counts    P30D_VapeEcig      1     294     264     136
# 4             Column Percents    P30D_VapeEcig      1  26.51%  19.31%   21.9%
# 2                      Counts    P30D_VapeEcig    All    1109    1367     621
# 5             Column Percents    P30D_VapeEcig    All  100.0%  100.0%  100.0%
# 0                      Counts  Susceptible_Cig      0     609     680     272
# 3             Column Percents  Susceptible_Cig      0  54.91%  63.61%  57.14%
# 1                      Counts  Susceptible_Cig      1     500     389     204
# 4             Column Percents  Susceptible_Cig      1  45.09%  36.39%  42.86%
# 2                      Counts  Susceptible_Cig    All    1109    1367     621
# 5             Column Percents  Susceptible_Cig    All  100.0%  100.0%  100.0%
#
# Project_Year    2022     All
# 0                733    3136
# 3             70.21%  75.73%
# 1                311    1005
# 4             29.79%  24.27%
# 2               1044    4141
# 5             100.0%  100.0%
# 0                 73    1634
# 3             59.35%  58.84%
# 1                 50    1143
# 4             40.65%  41.16%
# 2               1044    4141
# 5             100.0%  100.0%

# %%
#cross tabs rows
test_rows = xtab_rows(df, ['P30D_VapeEcig'], 'Project_Year')
#view(test_rows)
test_rows

# %%
#cross tabs all
test_all = xtab_all(df, ['P30D_VapeEcig'], 'Project_Year')
#view(test_all)
test_all

# %%
#missing data rows - cross tabs test: DROPS MISSING CASES
test_all_missing = xtab_all(df, ['Susceptible_Cig'], 'Project_Year')
test_all_missing

# %%
#missing data columns - cross tabs test: DROPS MISSING CASES
test_all_missing = xtab_all(df, ['Project_Year'], 'Susceptible_Cig')
test_all_missing

# %%
#Export examples
#test_freq.to_csv('test_freq.csv', index = False)
#test_cols.to_csv('test_cols.csv', index = False)
#test_rows.to_csv('test_rows.csv', index = False)

# %% [markdown]
# ## Tests - ChiSquare

# %%
#Chi sq - add sig column add input for what level of sig, input your sig level . 
test_cs = chi_sq(df, ['P30D_VapeEcig','P30D_Cig','P30D_Cigar','P30D_Hookah','P30D_Chew', 'P30D_Snus'], 'Project_Year', 0.05)
test_cs
# Out:
#               IV             DV               Chi-square test  results  \
# 0   Project_Year  P30D_VapeEcig  Pearson Chi-square ( 3.0) =   40.5100
# 1   Project_Year  P30D_VapeEcig                    p-value =    0.0000
# 2   Project_Year  P30D_VapeEcig                 Cramer's V =    0.0989
# 3   Project_Year       P30D_Cig  Pearson Chi-square ( 3.0) =   15.8347
# 4   Project_Year       P30D_Cig                    p-value =    0.0012
# 5   Project_Year       P30D_Cig                 Cramer's V =    0.0618
# 6   Project_Year     P30D_Cigar  Pearson Chi-square ( 3.0) =   15.1039
# 7   Project_Year     P30D_Cigar                    p-value =    0.0017
# 8   Project_Year     P30D_Cigar                 Cramer's V =    0.0604
# 9   Project_Year    P30D_Hookah  Pearson Chi-square ( 3.0) =   30.1355
# 10  Project_Year    P30D_Hookah                    p-value =    0.0000
# 11  Project_Year    P30D_Hookah                 Cramer's V =    0.0853
# 12  Project_Year      P30D_Chew  Pearson Chi-square ( 3.0) =    9.0004
# 13  Project_Year      P30D_Chew                    p-value =    0.0293
# 14  Project_Year      P30D_Chew                 Cramer's V =    0.0466
# 15  Project_Year      P30D_Snus  Pearson Chi-square ( 3.0) =    5.4085
# 16  Project_Year      P30D_Snus                    p-value =    0.1442
# 17  Project_Year      P30D_Snus                 Cramer's V =    0.0361
#
#    Significance (<0.05)
# 0
# 1                  True
# 2
# 3
# 4                  True
# 5
# 6
# 7                  True
# 8
# 9
# 10                 True
# 11
# 12
# 13                 True
# 14
# 15
# 16                False
# 17

# %%
#chi sq post hoc (bonferroni) - add sig level input here as well. Change "Reject Null" to "Significance" potetenially Y/N instead of true false. 
test_bon = chisq_posthoc_bon(df, ['P30D_VapeEcig','P30D_Cig','P30D_Cigar','P30D_Hookah','P30D_Chew'], 'Project_Year', 0.05)
#view(test_bon)
test_bon
# Out:
#              IV      IV pairs             DV  Original p value  \
# 0  Project_Year  (2020, 2021)  P30D_VapeEcig      2.028353e-01
# 1  Project_Year  (2020, 2022)  P30D_VapeEcig      2.972996e-09
# 2  Project_Year  (2020, 2019)  P30D_VapeEcig      2.503874e-05
# 3  Project_Year  (2021, 2022)  P30D_VapeEcig      5.490150e-04
# 4  Project_Year  (2021, 2019)  P30D_VapeEcig      3.841538e-02
# 5  Project_Year  (2022, 2019)  P30D_VapeEcig      1.002478e-01
# 0  Project_Year  (2020, 2021)       P30D_Cig      7.114893e-01
# 1  Project_Year  (2020, 2022)       P30D_Cig      7.315086e-04
# 2  Project_Year  (2020, 2019)       P30D_Cig      1.284314e-01
# 3  Project_Year  (2021, 2022)       P30D_Cig      2.428087e-03
# 4  Project_Year  (2021, 2019)       P30D_Cig      1.087490e-01
# 5  Project_Year  (2022, 2019)       P30D_Cig      8.733697e-02
# 0  Project_Year  (2020, 2021)     P30D_Cigar      7.113385e-03
# 1  Project_Year  (2020, 2022)     P30D_Cigar      6.313596e-01
# 2  Project_Year  (2020, 2019)     P30D_Cigar      1.484984e-01
# 3  Project_Year  (2021, 2022)     P30D_Cigar      2.950559e-02
# 4  Project_Year  (2021, 2019)     P30D_Cigar      1.986243e-04
# 5  Project_Year  (2022, 2019)     P30D_Cigar      6.207941e-02
# 0  Project_Year  (2020, 2021)    P30D_Hookah      9.518022e-01
# 1  Project_Year  (2020, 2022)    P30D_Hookah      1.083638e-05
# 2  Project_Year  (2020, 2019)    P30D_Hookah      9.629640e-01
# 3  Project_Year  (2021, 2022)    P30D_Hookah      1.998226e-03
# 4  Project_Year  (2021, 2019)    P30D_Hookah      1.000000e+00
# 5  Project_Year  (2022, 2019)    P30D_Hookah      8.214786e-05
# 0  Project_Year  (2020, 2021)      P30D_Chew      4.231377e-01
# 1  Project_Year  (2020, 2022)      P30D_Chew      1.154883e-01
# 2  Project_Year  (2020, 2019)      P30D_Chew      4.413945e-03
# 3  Project_Year  (2021, 2022)      P30D_Chew      7.527067e-01
# 4  Project_Year  (2021, 2019)      P30D_Chew      1.963593e-01
# 5  Project_Year  (2022, 2019)      P30D_Chew      2.995188e-01
#
#    Corrected p value  Significance (<0.05)
# 0       1.000000e+00                 False
# 1       1.783798e-08                  True
# 2       1.502324e-04                  True
# 3       3.294090e-03                  True
# 4       2.304923e-01                 False
# 5       6.014867e-01                 False
# 0       1.000000e+00                 False
# 1       4.389052e-03                  True
# 2       7.705886e-01                 False
# 3       1.456852e-02                  True
# 4       6.524939e-01                 False
# 5       5.240218e-01                 False
# 0       4.268031e-02                  True
# 1       1.000000e+00                 False
# 2       8.909902e-01                 False
# 3       1.770335e-01                 False
# 4       1.191746e-03                  True
# 5       3.724764e-01                 False
# 0       1.000000e+00                 False
# 1       6.501825e-05                  True
# 2       1.000000e+00                 False
# 3       1.198936e-02                  True
# 4       1.000000e+00                 False
# 5       4.928872e-04                  True
# 0       1.000000e+00                 False
# 1       6.929298e-01                 False
# 2       2.648367e-02                  True
# 3       1.000000e+00                 False
# 4       1.000000e+00                 False
# 5       1.000000e+00                 False

# %% [markdown]
# ## Tests - T_Test

# %%
#t-test 1 sample 
test_1samp = ttest_1sample(df, ['P30D_VapeEcig_Cont','P30D_Cig_Cont', 'P30D_Cigar_Cont'], [5,10,2], 0.05)
#test_1samp

# %%
##Two sample t-test function, just one test, not user facing
#def ttest_2sample_1(df, DV, IV, sub_category_1, sub_category_2, significance_level):
#    t_statistic, pval = scipy.stats.ttest_ind(df[DV][df[IV] == sub_category_1], 
#                                              df[DV][df[IV] == sub_category_2], nan_policy = 'omit')
#    ttest_df = pd.DataFrame(data = {'t statistic': t_statistic, 'p value': pval}, index = [0])
#    ttest_df['Significance' + ' (<' + str(significance_level) + ")"] = np.where(ttest_df['p value'] < significance_level, True, False)
#    ttest_df['DV'] = DV
#    ttest_df['IV'] = IV
#    ttest_df = ttest_df[['IV', 'DV', 't statistic', 'p value', 'Significance (<0.05)']]
#    return ttest_df
#
##Two sample t-test function, user facing, takes df, list of DV's, your IV, and your subcategories (only 2 allowed)
#def ttest_2sample(df, DV_list, IV, sub_category_1, sub_category_2, significance_level):
#    all_df = pd.DataFrame()
#    df[DV_list] = df[DV_list].astype(float) #convert dv's to float
#    for x in DV_list:
#        z = ttest_2sample_1(df, x, IV, sub_category_1, sub_category_2, significance_level)
#        all_df = all_df.append(z)
#    return all_df

# %%
#Two sample t-test function, just one test, not user facing
def ttest_2sample_1(df, DV, IV, subcategory_list, significance_level):
    t_statistic, pval = scipy.stats.ttest_ind(df[DV][df[IV] == subcategory_list[0]], 
                                              df[DV][df[IV] == subcategory_list[1]], nan_policy = 'omit')
    ttest_df = pd.DataFrame(data = {'t statistic': t_statistic, 'p value': pval}, index = [0])
    ttest_df['Significance' + ' (<' + str(significance_level) + ")"] = np.where(ttest_df['p value'] < significance_level, True, False)
    ttest_df['DV'] = DV
    ttest_df['IV'] = IV
    ttest_df['Subcategories'] = str(subcategory_list)
    ttest_df = ttest_df[['IV', "Subcategories", 'DV', 't statistic', 'p value', 'Significance (<0.05)']]
    return ttest_df

# %%
ttest_2sample_1(df, 'P30D_VapeEcig_Cont', 'Gender_Male', [0,1], 0.05)
# Out:
#             IV Subcategories                  DV  t statistic   p value  \
# 0  Gender_Male        [0, 1]  P30D_VapeEcig_Cont     0.319908  0.749313
#
#    Significance (<0.05)
# 0                 False

# %%
#Two sample t-test function, user facing, takes df, list of DV's, your IV, and your subcategories (only 2 allowed)
def ttest_2sample(df, DV_list, IV, subcategory_list, significance_level):
    all_df = pd.DataFrame()
    df[DV_list] = df[DV_list].astype(float) #convert dv's to float
    for x in DV_list:
        z = ttest_2sample_1(df, x, IV, subcategory_list, significance_level)
        all_df = all_df.append(z)
    return all_df

# %%
#t-test 2 sample - numeric subgroups
test_2samp = ttest_2sample(df,['P30D_VapeEcig_Cont', 'P30D_Cig_Cont', 'P30D_Cigar_Cont'], 'Gender_Male', [0,1],0.05)
test_2samp
# Out:
#             IV Subcategories                  DV  t statistic   p value  \
# 0  Gender_Male        [0, 1]  P30D_VapeEcig_Cont     0.319908  0.749313
# 0  Gender_Male        [0, 1]       P30D_Cig_Cont     0.269480  0.787789
# 0  Gender_Male        [0, 1]     P30D_Cigar_Cont     0.869341  0.385519
#
#    Significance (<0.05)
# 0                 False
# 0                 False
# 0                 False

# %%
#t-test 2 sample - categorical subgroups, cannot combine multipe subgroups w/o concat
test_2samp = ttest_2sample(df,['P30D_VapeEcig_Cont', 'P30D_Cig_Cont', 'P30D_Cigar_Cont'], 'Project_Year', ['2019','2020'],0.05)
test_2samp
# Out:
#              IV     Subcategories                  DV  t statistic  \
# 0  Project_Year  ['2019', '2020']  P30D_VapeEcig_Cont     5.474651
# 0  Project_Year  ['2019', '2020']       P30D_Cig_Cont    -0.979180
# 0  Project_Year  ['2019', '2020']     P30D_Cigar_Cont    -0.511173
#
#         p value  Significance (<0.05)
# 0  4.825399e-08                  True
# 0  3.275866e-01                 False
# 0  6.092756e-01                 False

# %%
#t-test paired
#NOTE: rare to use this - dont have the right data for this example but could see it work below with Gender 
test_paired = ttest_paired(df, ['P30D_VapeEcig_Cont','P30D_Cig_Cont', 'P30D_Cigar_Cont'], 'Gender_Female', 0.05)
test_paired

# %% [markdown]
# ## Tests - Correlations

# %%
#correlation pearson
test_corr = corr_pearson(df, ['P30D_VapeEcig_Cont','P30D_Cig_Cont', 'P30D_Cigar_Cont'], 'VAL_SCORE_ALT', 0.05)
#test_corr

# %% [markdown]
# ## Tests - KW_Functions

# %%
#KW assumption #normality test - ggplot 
test_shape = KW_shape_assumption(df,'P30D_VapeEcig_Cont', 'Project_Year', ['2019', '2020', '2021', '2022'])
test_shape
